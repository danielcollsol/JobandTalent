# %% [markdown]
# # Forecasting Task

# %% [markdown]
# The goal of this task is to build a model that forecasts the estimated total gross with the available data. The
# assignment description can be found using the following link: https://hackmd.io/biEvk-M2RNeGQ2WfCsCzzA
#
# In this section we will be working through linear regression with the following steps:
#
#     A. Data Analysis
#         1. Getting and setting up the data
#         2. Getting a data overview
#         3. Visualizing current data
#         4. Implementing a multivariate regression
#     B. Data Insights
#         1. Setting Training and Validation datasets
#         2. Predicting the estimated total gross
#         3. Residual Plots
#     C. Conclusion

# %% [markdown]
# # A. Data Analysis

# %% [markdown]
# ### 1. Getting and setting up the data

# %% [markdown]
# First we'll import our usual data analysis imports.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import datetime

# %% [markdown]
# Imports for plotting.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style('whitegrid')

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %% [markdown]
# Retrieve dataset from csv file to pandas DataFrame.

# %%
file = 'src/ml-faker_random_sample-contracts.csv'
df_raw = pd.read_csv(file)

# %% [markdown]
# Display head of the dataframe.

# %%
pd.set_option('display.max_columns', None)
df_raw.head()
# Out:
#    hiring_id    wp_id      hiring_status wp_status          business_model  \
# 0     166037  1723992      ready_to_work  upcoming         staffing_agency
# 1     569936  7254150  hiring_closed_out      paid         staffing_agency
# 2     352139  4706480  hiring_closed_out      paid         staffing_agency
# 3     313527  5362133  hiring_closed_out      paid  independent_contractor
# 4     425850  5002046  hiring_closed_out      paid         staffing_agency
#
#    company_id     company_name           hiring_created_at  \
# 0   299204747     Hurst-Garcia  2017-01-12 15:57:41.000000
# 1   237165491   Reese and Sons  2017-02-27 10:27:24.000000
# 2   168767792  Peterson-Wilson  2017-01-10 17:02:04.000000
# 3   211514331        Eaton LLC  2017-09-07 15:10:16.000000
# 4   146877029        Adams LLC  2017-07-04 08:33:55.000000
#
#                 wp_created_at hiring_starts_on hiring_ends_on wp_starts_on  \
# 0  2017-09-13 09:01:22.000000       2017-01-16     2021-01-15   2020-04-01
# 1  2017-03-19 13:50:52.000000       2017-02-27     2017-05-28   2017-03-20
# 2  2017-01-10 17:23:14.000000       2017-01-10     2018-01-09   2017-10-01
# 3  2018-02-01 16:15:30.000000       2017-09-04     2018-03-18   2018-01-29
# 4  2017-07-10 14:50:53.000000       2017-07-10     2017-08-28   2017-08-01
#
#    wp_ends_on job_function job_country  candidate_id   candidate_name  \
# 0  2020-04-30  support-guy          ES      49285305    Kenneth Price
# 1  2017-03-26    noise-guy          GB      57619821     Susan Santos
# 2  2017-10-31       f1-guy          ES      57564699     Susan Jensen
# 3  2018-02-04     drop-guy          GB      57795686      Michael Day
# 4  2017-08-28       f1-guy          ES      52752416  Christie Keller
#
#    total_gross  est_total_gross currency  issue_reported contract_type  \
# 0  1114.285714      1114.285714      EUR           False     full_time
# 1   346.970000       364.877990      GBP           False      by_hours
# 2  1061.660000      1041.660000      EUR           False     full_time
# 3   455.000000       390.840322      GBP            True     full_time
# 4   664.280000      1031.968000      EUR           False     full_time
#
#    gross_wage_amount gross_wage_time_unit gross_wage_currency_id  \
# 0                650                 hour                    EUR
# 1                750                 hour                    GBP
# 2             104166                month                    EUR
# 3                800                 hour                    GBP
# 4             110568                month                    EUR
#
#   work_period_unit  work_period_amount  work_period_hours  fee_percentage  \
# 0            month                 2.0               40.0            3.92
# 1             week                12.0               40.0           10.09
# 2            month                12.0               40.0            5.00
# 3             week                12.0               40.0            9.00
# 4            month                 1.6               40.0            0.00
#
#   cancellation_date  is_outsourced
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN

# %% [markdown]
# Check column datatypes

# %%
print('Columns datetypes:')
df_raw.dtypes
# Out:
# Columns datetypes:
# hiring_id                   int64
# wp_id                       int64
# hiring_status              object
# wp_status                  object
# business_model             object
# company_id                  int64
# company_name               object
# hiring_created_at          object
# wp_created_at              object
# hiring_starts_on           object
# hiring_ends_on             object
# wp_starts_on               object
# wp_ends_on                 object
# job_function               object
# job_country                object
# candidate_id                int64
# candidate_name             object
# total_gross               float64
# est_total_gross           float64
# currency                   object
# issue_reported               bool
# contract_type              object
# gross_wage_amount           int64
# gross_wage_time_unit       object
# gross_wage_currency_id     object
# work_period_unit           object
# work_period_amount        float64
# work_period_hours         float64
# fee_percentage            float64
# cancellation_date          object
# is_outsourced             float64
# dtype: object

# %% [markdown]
# Let's convert string dates (object) into datetime datatype

# %%
columns_2convert_2datetime = ['hiring_created_at','hiring_starts_on','hiring_ends_on',
                              'wp_created_at','wp_starts_on','wp_ends_on']
for column in columns_2convert_2datetime:
    df_raw[column] = pd.to_datetime(df_raw[column])
#Save processed dataframe with different name
df = df_raw.copy()

# %%
df.dtypes
# Out:
# hiring_id                          int64
# wp_id                              int64
# hiring_status                     object
# wp_status                         object
# business_model                    object
# company_id                         int64
# company_name                      object
# hiring_created_at         datetime64[ns]
# wp_created_at             datetime64[ns]
# hiring_starts_on          datetime64[ns]
# hiring_ends_on            datetime64[ns]
# wp_starts_on              datetime64[ns]
# wp_ends_on                datetime64[ns]
# job_function                      object
# job_country                       object
# candidate_id                       int64
# candidate_name                    object
# total_gross                      float64
# est_total_gross                  float64
# currency                          object
# issue_reported                      bool
# contract_type                     object
# gross_wage_amount                  int64
# gross_wage_time_unit              object
# gross_wage_currency_id            object
# work_period_unit                  object
# work_period_amount               float64
# work_period_hours                float64
# fee_percentage                   float64
# cancellation_date                 object
# is_outsourced                    float64
# dtype: object

# %% [markdown]
# ### 2. Getting a data overview

# %% [markdown]
# Get some basic information about the this 20000 rows x 12 columns dataset.

# %%
print('Hiring status categories:')
print(list(df['hiring_status'].unique()), '\n')

print('Hiring creation date :')
print('     min: ', df['hiring_created_at'].min())
print('     max: ', df['hiring_created_at'].max())
print('Note: Seems to be correct.','\n')

print('Hiring starting date :')
print('     min: ', df['hiring_starts_on'].min())
print('     max: ', df['hiring_starts_on'].max())
print('Note: Seems to be correct.','\n')

print('Is always the hiring starting date before than the ending date?')
print((df['hiring_starts_on'] <= df['hiring_ends_on']).value_counts())
print('Note: 932 hirings starts and ends on the same day. No inconsistency','\n')

print('Is always the hiring registration date before than the starting date?')
print((df['hiring_created_at'].dt.strftime('%Y/%m/%d') <= df['hiring_starts_on'].dt.strftime('%Y/%m/%d')).value_counts())
print('Note: Might be common to register the hiring after the starting date BUT probable inconsistency.','\n')

print('Work period status categories:')
print(list(df['wp_status'].unique()), '\n')

print("Is always the work permit registration date before than the wp's starting date?")
print((df['wp_created_at'].dt.strftime('%Y/%m/%d') <= df['wp_starts_on'].dt.strftime('%Y/%m/%d')).value_counts())
print('Note: Might be common to register the hiring after the starting date BUT probable inconsistency.','\n')

print('Is always the work permit starting date before than the ending date?')
print((df['wp_starts_on'] < df['wp_ends_on']).value_counts())
print('Error found: 2 rows seem to be wrong and for the 1272 others, the work permit starts and ends on the same day.','\n')
# Out:
# Hiring status categories:
# ['ready_to_work', 'hiring_closed_out', 'hiring_cancelled', 'pending_cancellation', 'employer_ready_to_work']
#
# Hiring creation date :
#      min:  2016-10-14 10:09:00
#      max:  2018-03-20 12:17:37
# Note: Seems to be correct.
#
# Hiring starting date :
#      min:  2015-02-02 00:00:00
#      max:  2019-10-25 00:00:00
# Note: Seems to be correct.
#
# Is always the hiring starting date before than the ending date?
# True    20000
# dtype: int64
# Note: 932 hirings starts and ends on the same day. No inconsistency
#
# Is always the hiring registration date before than the starting date?
# True     15697
# False     4303
# dtype: int64
# Note: Might be common to register the hiring after the starting date BUT probable inconsistency.
#
# Work period status categories:
# ['upcoming', 'paid', 'payslip_generated', 'working', 'reviewed', 'timesheet_missing', 'acceptance_pending']
#
# Is always the work permit registration date before than the wp's starting date?
# True     15010
# False     4990
# dtype: int64
# Note: Might be common to register the hiring after the starting date BUT probable inconsistency.
#
# Is always the work permit starting date before than the ending date?
# True     18726
# False     1274
# dtype: int64
# Error found: 2 rows seem to be wrong and for the 1272 others, the work permit starts and ends on the same day.

# %% [markdown]
# Check those hirings started before having the working permit.

# %%
df[df['wp_starts_on'] < df['hiring_starts_on']]
# Out:
#       hiring_id    wp_id      hiring_status wp_status   business_model  \
# 7988     561482  3584426  hiring_closed_out      paid  staffing_agency
#
#       company_id company_name   hiring_created_at       wp_created_at  \
# 7988    83773059   Hall Group 2017-06-30 10:06:09 2017-06-30 14:23:43
#
#      hiring_starts_on hiring_ends_on wp_starts_on wp_ends_on  job_function  \
# 7988       2017-08-28     2017-08-28   2017-07-03 2017-07-03  annoying-guy
#
#      job_country  candidate_id candidate_name  total_gross  est_total_gross  \
# 7988          ES      57565447   Timothy Frye       119.07            87.28
#
#      currency  issue_reported contract_type  gross_wage_amount  \
# 7988      EUR           False      by_hours               1091
#
#      gross_wage_time_unit gross_wage_currency_id work_period_unit  \
# 7988                 hour                    EUR              day
#
#       work_period_amount  work_period_hours  fee_percentage cancellation_date  \
# 7988                 1.0                8.0             5.0               NaN
#
#       is_outsourced
# 7988            NaN

# %% [markdown]
# Check those hirings that will require or have required to request a working permit before the end of the contract.

# %%
df[df['wp_ends_on'] < df['hiring_ends_on']]
# Out:
#        hiring_id    wp_id      hiring_status          wp_status  \
# 0         166037  1723992      ready_to_work           upcoming
# 1         569936  7254150  hiring_closed_out               paid
# 2         352139  4706480  hiring_closed_out               paid
# 3         313527  5362133  hiring_closed_out               paid
# 5         148520  6879092  hiring_closed_out  payslip_generated
# ...          ...      ...                ...                ...
# 19995     644054  7599990  hiring_closed_out               paid
# 19996     880498  5606394      ready_to_work  payslip_generated
# 19997     368202  3299155  hiring_closed_out           reviewed
# 19998     471586  7424423      ready_to_work               paid
# 19999     653377  3838055   hiring_cancelled           reviewed
#
#                business_model  company_id                  company_name  \
# 0             staffing_agency   299204747                  Hurst-Garcia
# 1             staffing_agency   237165491                Reese and Sons
# 2             staffing_agency   168767792               Peterson-Wilson
# 3      independent_contractor   211514331                     Eaton LLC
# 5             staffing_agency   396877181               Gonzales-Zuniga
# ...                       ...         ...                           ...
# 19995         staffing_agency   361157247                     Moore LLC
# 19996  independent_contractor   343058694  Howard, Robinson and Simpson
# 19997  independent_contractor   211514331                     Eaton LLC
# 19998         staffing_agency   145692788                  Lopez-Rivera
# 19999  independent_contractor   211514331                Smith and Sons
#
#         hiring_created_at       wp_created_at hiring_starts_on hiring_ends_on  \
# 0     2017-01-12 15:57:41 2017-09-13 09:01:22       2017-01-16     2021-01-15
# 1     2017-02-27 10:27:24 2017-03-19 13:50:52       2017-02-27     2017-05-28
# 2     2017-01-10 17:02:04 2017-01-10 17:23:14       2017-01-10     2018-01-09
# 3     2017-09-07 15:10:16 2018-02-01 16:15:30       2017-09-04     2018-03-18
# 5     2016-10-14 10:09:00 2016-10-14 14:04:55       2016-10-17     2017-01-17
# ...                   ...                 ...              ...            ...
# 19995 2017-09-14 15:21:01 2017-09-18 09:54:33       2017-09-18     2017-12-15
# 19996 2017-06-22 08:57:22 2017-06-22 08:57:42       2017-03-17     2017-06-25
# 19997 2017-09-08 09:45:19 2017-09-27 23:46:06       2017-09-04     2018-03-25
# 19998 2017-08-24 16:48:56 2017-08-28 15:47:17       2017-08-29     2018-08-28
# 19999 2017-06-22 10:55:47 2017-09-14 09:27:56       2017-06-03     2017-11-18
#
#       wp_starts_on wp_ends_on job_function job_country  candidate_id  \
# 0       2020-04-01 2020-04-30  support-guy          ES      49285305
# 1       2017-03-20 2017-03-26    noise-guy          GB      57619821
# 2       2017-10-01 2017-10-31       f1-guy          ES      57564699
# 3       2018-01-29 2018-02-04     drop-guy          GB      57795686
# 5       2016-11-01 2016-11-30       editor          ES      41650643
# ...            ...        ...          ...         ...           ...
# 19995   2017-10-01 2017-10-31     minister          ES      57011657
# 19996   2017-03-27 2017-04-02     drop-guy          GB      55881339
# 19997   2017-09-18 2017-09-24     drop-guy          GB      57796388
# 19998   2017-11-01 2017-11-30       f1-guy          ES      57782167
# 19999   2017-08-21 2017-08-27     drop-guy          GB      57734605
#
#           candidate_name  total_gross  est_total_gross currency  \
# 0          Kenneth Price  1114.285714      1114.285714      EUR
# 1           Susan Santos   346.970000       364.877990      GBP
# 2           Susan Jensen  1061.660000      1041.660000      EUR
# 3            Michael Day   455.000000       390.840322      GBP
# 5         Bradley Barron  1058.280000      1042.760000      EUR
# ...                  ...          ...              ...      ...
# 19995      Bridget Ayala  1062.000000      1062.000000      EUR
# 19996      James Perkins   390.840322       390.840322      GBP
# 19997     Timothy Porter   582.000000       390.840322      GBP
# 19998  Savannah Thornton  1292.930000      1258.340000      EUR
# 19999  Jennifer Harrison   439.000000       598.538978      GBP
#
#        issue_reported contract_type  gross_wage_amount gross_wage_time_unit  \
# 0               False     full_time                650                 hour
# 1               False      by_hours                750                 hour
# 2               False     full_time             104166                month
# 3                True     full_time                800                 hour
# 5               False     full_time             104276                month
# ...               ...           ...                ...                  ...
# 19995           False     full_time             106200                month
# 19996           False     full_time                800                 hour
# 19997            True     full_time                800                 hour
# 19998           False     full_time             125834                month
# 19999            True     full_time               1200                 hour
#
#       gross_wage_currency_id work_period_unit  work_period_amount  \
# 0                        EUR            month                 2.0
# 1                        GBP             week                12.0
# 2                        EUR            month                12.0
# 3                        GBP             week                12.0
# 5                        EUR            month                 3.0
# ...                      ...              ...                 ...
# 19995                    EUR            month                 2.9
# 19996                    GBP             week                12.0
# 19997                    GBP             week                12.0
# 19998                    EUR            month                 3.0
# 19999                    GBP             week                12.0
#
#        work_period_hours  fee_percentage cancellation_date  is_outsourced
# 0                   40.0            3.92               NaN            NaN
# 1                   40.0           10.09               NaN            NaN
# 2                   40.0            5.00               NaN            NaN
# 3                   40.0            9.00               NaN            NaN
# 5                   40.0           10.00               NaN            NaN
# ...                  ...             ...               ...            ...
# 19995               40.0           10.00               NaN            NaN
# 19996               40.0            9.30               NaN            NaN
# 19997               40.0            9.00               NaN            NaN
# 19998               40.0            6.00               NaN            NaN
# 19999               40.0           13.00        2017-10-21            NaN
#
# [16706 rows x 31 columns]

# %% [markdown]
# Check null values.

# %%
for column in df:
    print(df[column].isnull().value_counts())
# Out:
# False    20000
# Name: hiring_id, dtype: int64
# False    20000
# Name: wp_id, dtype: int64
# False    20000
# Name: hiring_status, dtype: int64
# False    20000
# Name: wp_status, dtype: int64
# False    20000
# Name: business_model, dtype: int64
# False    20000
# Name: company_id, dtype: int64
# False    20000
# Name: company_name, dtype: int64
# False    20000
# Name: hiring_created_at, dtype: int64
# False    20000
# Name: wp_created_at, dtype: int64
# False    20000
# Name: hiring_starts_on, dtype: int64
# False    20000
# Name: hiring_ends_on, dtype: int64
# False    20000
# Name: wp_starts_on, dtype: int64
# False    20000
# Name: wp_ends_on, dtype: int64
# False    20000
# Name: job_function, dtype: int64
# False    20000
# Name: job_country, dtype: int64
# False    20000
# Name: candidate_id, dtype: int64
# False    20000
# Name: candidate_name, dtype: int64
# False    20000
# Name: total_gross, dtype: int64
# False    20000
# Name: est_total_gross, dtype: int64
# False    20000
# Name: currency, dtype: int64
# False    20000
# Name: issue_reported, dtype: int64
# False    20000
# Name: contract_type, dtype: int64
# False    20000
# Name: gross_wage_amount, dtype: int64
# False    20000
# Name: gross_wage_time_unit, dtype: int64
# False    20000
# Name: gross_wage_currency_id, dtype: int64
# False    20000
# Name: work_period_unit, dtype: int64
# False    20000
# Name: work_period_amount, dtype: int64
# False    20000
# Name: work_period_hours, dtype: int64
# False    20000
# Name: fee_percentage, dtype: int64
# True     14821
# False     5179
# Name: cancellation_date, dtype: int64
# True    20000
# Name: is_outsourced, dtype: int64

# %% [markdown]
# ### 3. Visualizing current data

# %% [markdown]
# Let's see if there is any particular pattern among the salary values? (for job_function , company, period of the year, etc.

# %%
df['total_gross']
# Out:
# 0        1114.285714
# 1         346.970000
# 2        1061.660000
# 3         455.000000
# 4         664.280000
#             ...
# 19995    1062.000000
# 19996     390.840322
# 19997     582.000000
# 19998    1292.930000
# 19999     439.000000
# Name: total_gross, Length: 20000, dtype: float64

# %%
plt.hist(df['total_gross'], bins=[0,200,400,600,800,1000, 1200, 1400, 1600, 1800], stacked = True)
# Out:
# (array([3838., 3119., 2812., 1864., 1678., 2117., 2167., 1030.,  505.]),
#  array([   0,  200,  400,  600,  800, 1000, 1200, 1400, 1600, 1800]),
#  <a list of 9 Patch objects>)

# %%
df[df['total_gross']> 500]
# Out:
#        hiring_id    wp_id      hiring_status          wp_status  \
# 0         166037  1723992      ready_to_work           upcoming
# 2         352139  4706480  hiring_closed_out               paid
# 4         425850  5002046  hiring_closed_out               paid
# 5         148520  6879092  hiring_closed_out  payslip_generated
# 6         458779  3278989   hiring_cancelled               paid
# ...          ...      ...                ...                ...
# 19993     786477   123348      ready_to_work               paid
# 19994     678044  4081089  hiring_closed_out               paid
# 19995     644054  7599990  hiring_closed_out               paid
# 19997     368202  3299155  hiring_closed_out           reviewed
# 19998     471586  7424423      ready_to_work               paid
#
#                business_model  company_id     company_name  \
# 0             staffing_agency   299204747     Hurst-Garcia
# 2             staffing_agency   168767792  Peterson-Wilson
# 4             staffing_agency   146877029        Adams LLC
# 5             staffing_agency   396877181  Gonzales-Zuniga
# 6             staffing_agency    28940115       Davies LLC
# ...                       ...         ...              ...
# 19993  independent_contractor   211514331        Eaton LLC
# 19994  independent_contractor   211514331        Eaton LLC
# 19995         staffing_agency   361157247        Moore LLC
# 19997  independent_contractor   211514331        Eaton LLC
# 19998         staffing_agency   145692788     Lopez-Rivera
#
#         hiring_created_at       wp_created_at hiring_starts_on hiring_ends_on  \
# 0     2017-01-12 15:57:41 2017-09-13 09:01:22       2017-01-16     2021-01-15
# 2     2017-01-10 17:02:04 2017-01-10 17:23:14       2017-01-10     2018-01-09
# 4     2017-07-04 08:33:55 2017-07-10 14:50:53       2017-07-10     2017-08-28
# 5     2016-10-14 10:09:00 2016-10-14 14:04:55       2016-10-17     2017-01-17
# 6     2017-04-07 13:28:46 2017-11-13 14:23:48       2017-04-08     2018-04-07
# ...                   ...                 ...              ...            ...
# 19993 2017-12-13 15:33:49 2018-01-18 17:07:15       2017-12-13     2018-03-25
# 19994 2017-08-08 13:50:26 2018-02-15 19:04:21       2017-08-08     2018-03-25
# 19995 2017-09-14 15:21:01 2017-09-18 09:54:33       2017-09-18     2017-12-15
# 19997 2017-09-08 09:45:19 2017-09-27 23:46:06       2017-09-04     2018-03-25
# 19998 2017-08-24 16:48:56 2017-08-28 15:47:17       2017-08-29     2018-08-28
#
#       wp_starts_on wp_ends_on job_function job_country  candidate_id  \
# 0       2020-04-01 2020-04-30  support-guy          ES      49285305
# 2       2017-10-01 2017-10-31       f1-guy          ES      57564699
# 4       2017-08-01 2017-08-28       f1-guy          ES      52752416
# 5       2016-11-01 2016-11-30       editor          ES      41650643
# 6       2018-01-01 2018-01-10       f1-guy          ES      57648833
# ...            ...        ...          ...         ...           ...
# 19993   2018-01-22 2018-01-28     drop-guy          GB      57858370
# 19994   2018-02-19 2018-02-25     drop-guy          GB      57737119
# 19995   2017-10-01 2017-10-31     minister          ES      57011657
# 19997   2017-09-18 2017-09-24     drop-guy          GB      57796388
# 19998   2017-11-01 2017-11-30       f1-guy          ES      57782167
#
#           candidate_name  total_gross  est_total_gross currency  \
# 0          Kenneth Price  1114.285714      1114.285714      EUR
# 2           Susan Jensen  1061.660000      1041.660000      EUR
# 4        Christie Keller   664.280000      1031.968000      EUR
# 5         Bradley Barron  1058.280000      1042.760000      EUR
# 6          Kathy Mathews   554.940000       419.446667      EUR
# ...                  ...          ...              ...      ...
# 19993        Jessica Ray   516.000000       390.840322      GBP
# 19994      Julian Barnes   740.000000       390.840322      GBP
# 19995      Bridget Ayala  1062.000000      1062.000000      EUR
# 19997     Timothy Porter   582.000000       390.840322      GBP
# 19998  Savannah Thornton  1292.930000      1258.340000      EUR
#
#        issue_reported contract_type  gross_wage_amount gross_wage_time_unit  \
# 0               False     full_time                650                 hour
# 2               False     full_time             104166                month
# 4               False     full_time             110568                month
# 5               False     full_time             104276                month
# 6               False     full_time             125834                month
# ...               ...           ...                ...                  ...
# 19993            True     full_time                800                 hour
# 19994            True     full_time                800                 hour
# 19995           False     full_time             106200                month
# 19997            True     full_time                800                 hour
# 19998           False     full_time             125834                month
#
#       gross_wage_currency_id work_period_unit  work_period_amount  \
# 0                        EUR            month                 2.0
# 2                        EUR            month                12.0
# 4                        EUR            month                 1.6
# 5                        EUR            month                 3.0
# 6                        EUR            month                12.0
# ...                      ...              ...                 ...
# 19993                    GBP             week                12.0
# 19994                    GBP             week                12.0
# 19995                    EUR            month                 2.9
# 19997                    GBP             week                12.0
# 19998                    EUR            month                 3.0
#
#        work_period_hours  fee_percentage cancellation_date  is_outsourced
# 0                   40.0            3.92               NaN            NaN
# 2                   40.0            5.00               NaN            NaN
# 4                   40.0            0.00               NaN            NaN
# 5                   40.0           10.00               NaN            NaN
# 6                   40.0            0.00        2018-01-10            NaN
# ...                  ...             ...               ...            ...
# 19993               40.0            9.00               NaN            NaN
# 19994               40.0            9.00               NaN            NaN
# 19995               40.0           10.00               NaN            NaN
# 19997               40.0            9.00               NaN            NaN
# 19998               40.0            6.00               NaN            NaN
#
# [11691 rows x 31 columns]
